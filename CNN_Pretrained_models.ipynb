# %%
from keras.preprocessing import image
from keras.applications.resnet50 import ResNet50
from keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
model = ResNet50(weights = 'imagenet')

# %%
img = image.load_img('/content/th (1chair).jpg', target_size = (224,224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x = preprocess_input(x)  #process would also be based on the pretrained model we are using

# For example, if you’re using a model like VGG16, ResNet, or InceptionV3 from Keras, preprocess_input() scales pixel values and/or normalizes the image in a way that is compatible with the model's training data.
# For models like VGG16 or ResNet, this might involve scaling the pixel values (e.g., dividing by 255), subtracting the mean pixel values from the ImageNet dataset, or doing other normalization based on the pre-trained model's specifications.

# %%
x
# Out:
# array([[[[146.061  , 138.22101, 122.32   ],
#          [146.061  , 138.22101, 122.32   ],
#          [146.061  , 138.22101, 122.32   ],
#          ...,
#          [148.061  , 135.22101, 128.32   ],
#          [148.061  , 135.22101, 128.32   ],
#          [148.061  , 135.22101, 128.32   ]],
#
#         [[146.061  , 137.22101, 124.32   ],
#          [146.061  , 137.22101, 124.32   ],
#          [146.061  , 137.22101, 124.32   ],
#          ...,
#          [148.061  , 135.22101, 128.32   ],
#          [148.061  , 135.22101, 128.32   ],
#          [148.061  , 135.22101, 128.32   ]],
#
#         [[146.061  , 137.22101, 124.32   ],
#          [146.061  , 137.22101, 124.32   ],
#          [146.061  , 137.22101, 124.32   ],
#          ...,
#          [148.061  , 135.22101, 128.32   ],
#          [148.061  , 135.22101, 128.32   ],
#          [148.061  , 135.22101, 128.32   ]],
#
#         ...,
#
#         [[148.061  , 135.22101, 128.32   ],
#          [148.061  , 135.22101, 128.32   ],
# ...

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x.shape
# Out:
# (1, 224, 224, 3)

# %%
pred = model.predict(x)
print('Predicted', decode_predictions(pred, top = 3)[0])

#Pomeranian - dog type - not just the class but also dog type with hierarchy
#with chair - folding chair
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# Predicted [('n03376595', 'folding_chair', 0.29257983), ('n03125729', 'cradle', 0.2905844), ('n02804414', 'bassinet', 0.26210758)]

# %%
from tensorflow.keras.applications.vgg16 import VGG16, decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np

# Load the pre-trained VGG16 model
model = VGG16(weights='imagenet')

# Load an image and preprocess it (same steps as before)
img_path = '/content/Tomato_je.jpg.crdownload'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = x / 255.0  # Preprocessing: scale pixel values (specific for VGG16)

# Predict the class probabilities for the image
predictions = model.predict(x)

# Decode the predictions to get class labels and probabilities
decoded_predictions = decode_predictions(predictions, top=3)

# Print the decoded predictions
for i, (imagenet_id, label, score) in enumerate(decoded_predictions[0]):
    print(f"Rank {i + 1}: {label} ({score * 100:.2f}%)")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 752ms/step
# Rank 1: toilet_tissue (3.57%)
# Rank 2: mosquito_net (3.34%)
# Rank 3: electric_fan (1.75%)

# %%
from keras.applications import VGG16
model = VGG16()

# %%
model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ...
